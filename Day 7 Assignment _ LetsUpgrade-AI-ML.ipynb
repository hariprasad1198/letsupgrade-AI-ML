# %% [markdown]
# # Assignment Day 7 | 14th July 2020
# ## HR Data Analysis for attrition

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\Admin\Downloads\general_data.csv")
data
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
data.shape
# Out:
# (4410, 24)

# %% [markdown]
# ### Here the target variable is attrition

# %% [markdown]
# #### we know that there is no relation with attrition to employeeid so removing this column

# %%
data.drop(columns='EmployeeID',inplace=True)

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'Gender', 'JobLevel',
#        'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'Over18', 'PercentSalaryHike', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ##### Checking Data Type of Columns

# %%
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# Gender                      object
# JobLevel                     int64
# JobRole                     object
# MaritalStatus               object
# MonthlyIncome                int64
# NumCompaniesWorked         float64
# Over18                      object
# PercentSalaryHike            int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears          float64
# TrainingTimesLastYear        int64
# YearsAtCompany               int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# #### checking for null values

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# ### Droping out all null / NA columns

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
data.isna().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %% [markdown]
# ### Description of the data

# %%
data.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount     JobLevel  \
# count  4382.000000       4382.000000  4382.000000         4382.0  4382.000000
# mean     36.933364          9.198996     2.912369            1.0     2.063898
# std       9.137272          8.105396     1.024728            0.0     1.106115
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0     1.000000
# 50%      36.000000          7.000000     3.000000            1.0     2.000000
# 75%      43.000000         14.000000     4.000000            1.0     3.000000
# max      60.000000         29.000000     5.000000            1.0     5.000000
#
#        MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StandardHours  \
# count    4382.000000         4382.000000        4382.000000         4382.0
# mean    65061.702419            2.693291          15.210634            8.0
# ...

# %% [markdown]
# ### geting the list of all countinus columns

# %%
data.describe().columns
# Out:
# Index(['Age', 'DistanceFromHome', 'Education', 'EmployeeCount', 'JobLevel',
#        'MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ### checking for outliers

# %%
all_countinous_columns = ['Age', 'DistanceFromHome', 'EmployeeCount',
       'MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike',
       'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
       'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']

for one_countinous_column in all_countinous_columns:
    print('Box Plot For ',one_countinous_column)
    plt.boxplot(data[one_countinous_column])
    plt.show()
# Out:
# Box Plot For  Age
# Box Plot For  DistanceFromHome
# Box Plot For  EmployeeCount
# Box Plot For  MonthlyIncome
# Box Plot For  NumCompaniesWorked
# Box Plot For  PercentSalaryHike
# Box Plot For  StandardHours
# Box Plot For  StockOptionLevel
# Box Plot For  TotalWorkingYears
# Box Plot For  TrainingTimesLastYear
# Box Plot For  YearsAtCompany
# Box Plot For  YearsSinceLastPromotion
# Box Plot For  YearsWithCurrManager

# %% [markdown]
# ### As we can see there is no outlier for: Age, Distace From Home, Employee Count, Percent Salary Hike, Standerd Hours
# ### we can also see that there are few outliers in MonthlyIncome, NumCompaniesWorked, Stock OptionLevel, TotalWorkingYears, TrainingTimes Last Year, Years At Company, Years SinceLast Promotion and YearWithCurrent Manager

# %% [markdown]
# ## Creating Dummies for all categorical string value to correlate in better way

# %%
data = pd.get_dummies(data,drop_first=True)
data
# Out:
#       Age  DistanceFromHome  Education  EmployeeCount  JobLevel  \
# 0      51                 6          2              1         1
# 1      31                10          1              1         1
# 2      32                17          4              1         4
# 3      38                 2          5              1         3
# 4      32                10          1              1         1
# ...   ...               ...        ...            ...       ...
# 4404   29                 4          3              1         2
# 4405   42                 5          4              1         1
# 4406   29                 2          4              1         1
# 4407   25                25          2              1         2
# 4408   42                18          2              1         1
#
#       MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StandardHours  \
# 0            131160                 1.0                 11              8
# ...

# %%
data.columns
# Out:
# Index(['Age', 'DistanceFromHome', 'Education', 'EmployeeCount', 'JobLevel',
#        'MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition_Yes',
#        'BusinessTravel_Travel_Frequently', 'BusinessTravel_Travel_Rarely',
#        'Department_Research & Development', 'Department_Sales',
#        'EducationField_Life Sciences', 'EducationField_Marketing',
#        'EducationField_Medical', 'EducationField_Other',
#        'EducationField_Technical Degree', 'Gender_Male',
#        'JobRole_Human Resources', 'JobRole_Laboratory Technician',
#        'JobRole_Manager', 'JobRole_Manufacturing Director',
#        'JobRole_Research Director', 'JobRole_Research Scientist',
#        'JobRole_Sales Executive', 'JobRole_Sales Representative',
#        'MaritalStatus_Married', 'MaritalStatus_Single'],
# ...

# %% [markdown]
# ### Lets see corrleation of Each variable to each others

# %%
data.corr()
# Out:
#                                         Age  DistanceFromHome  Education  \
# Age                                1.000000          0.007376  -0.033900
# DistanceFromHome                   0.007376          1.000000  -0.007491
# Education                         -0.033900         -0.007491   1.000000
# EmployeeCount                           NaN               NaN        NaN
# JobLevel                          -0.001137         -0.039990   0.045822
# MonthlyIncome                     -0.045163         -0.022757   0.007289
# NumCompaniesWorked                 0.299527         -0.014449  -0.016210
# PercentSalaryHike                 -0.032561          0.037720  -0.041054
# StandardHours                           NaN               NaN        NaN
# StockOptionLevel                  -0.031504          0.009353   0.002386
# TotalWorkingYears                  0.680037          0.009574  -0.009228
# TrainingTimesLastYear             -0.028962         -0.008957   0.009939
# ...

# %% [markdown]
# ### Correlation with the target variable

# %%
data.corr()['Attrition_Yes']
# Out:
# Age                                 -0.158399
# DistanceFromHome                    -0.009449
# Education                           -0.017106
# EmployeeCount                             NaN
# JobLevel                            -0.012382
# MonthlyIncome                       -0.030160
# NumCompaniesWorked                   0.042831
# PercentSalaryHike                    0.033153
# StandardHours                             NaN
# StockOptionLevel                    -0.008164
# TotalWorkingYears                   -0.169670
# TrainingTimesLastYear               -0.047586
# YearsAtCompany                      -0.133003
# YearsSinceLastPromotion             -0.031423
# YearsWithCurrManager                -0.154692
# Attrition_Yes                        1.000000
# BusinessTravel_Travel_Frequently     0.113231
# BusinessTravel_Travel_Rarely        -0.048146
# Department_Research & Development   -0.015583
# Department_Sales                    -0.017531
# ...

# %%
## sorting value to see the clear relation
correlation_attrition = dict(data.corr()['Attrition_Yes'])
correlation_attrition_sorted = sorted(correlation_attrition.items(),key=lambda item : item[1])

## converting the to DataFrame
correlation_attrition_df = pd.DataFrame(correlation_attrition_sorted)

## droping the last self row relation 
correlation_attrition_df = correlation_attrition_df.drop(35,axis = 0)

## dropign tha NA value
correlation_attrition_df.dropna(inplace=True)
correlation_attrition_df
# Out:
#                                     0         1
# 0                                 Age -0.158399
# 1                YearsWithCurrManager -0.154692
# 2                       MonthlyIncome -0.030160
# 3                           Education -0.017106
# 4                            JobLevel -0.012382
# 5                    DistanceFromHome -0.009449
# 7                   TotalWorkingYears -0.169670
# 8                      YearsAtCompany -0.133003
# 9               MaritalStatus_Married -0.089627
# 10       BusinessTravel_Travel_Rarely -0.048146
# 11              TrainingTimesLastYear -0.047586
# 12     JobRole_Manufacturing Director -0.043931
# 13    EducationField_Technical Degree -0.039318
# 14            YearsSinceLastPromotion -0.031423
# 15               EducationField_Other -0.025071
# 16                   Department_Sales -0.017531
# 17                    JobRole_Manager -0.017256
# 18  Department_Research & Development -0.015583
# 19            JobRole_Human Resources -0.013737
# ...

# %% [markdown]
# # VISUALISING THE DATA

# %%
plt.rcParams['figure.figsize'] = [50, 20]
font = {'family' : 'serif',
        'weight' : 'bold',
        'size'   : 35}

plt.rc('font', **font)

# %%
plt.xticks(rotation='vertical')
plt.bar(correlation_attrition_df[0],correlation_attrition_df[1])
# Out:
# <BarContainer object of 33 artists>

# %% [markdown]
# ## We can clear say that
# * Employee who travel Frequently and Whoes Martials Status is single is more like to leave the company
# * Employee with high age is less likly leave the compnay
# * Employee Who is working With Large number of years with his manager is less likely to leave the company
# * Employee who is working with High number of year is less chance to leave the company
# * Also Old employee have less chance to remove the company
# * There is no effect of EducationalField in which they are to the attrition
# * Person Whos are married less likely to leave the company
