# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sb
from scipy.stats import pearsonr

# %%
df = pd.read_csv(r"C:\Users\Admin\Downloads\general_data.csv").T
print(df)
# Out:
#                                               0                       1     \
# Age                                             51                      31
# Attrition                                       No                     Yes
# BusinessTravel                       Travel_Rarely       Travel_Frequently
# Department                                   Sales  Research & Development
# DistanceFromHome                                 6                      10
# Education                                        2                       1
# EducationField                       Life Sciences           Life Sciences
# EmployeeCount                                    1                       1
# EmployeeID                                       1                       2
# Gender                                      Female                  Female
# JobLevel                                         1                       1
# ...

# %%
df.head()
# Out:
#                            0                       1     \
# Age                          51                      31
# Attrition                    No                     Yes
# BusinessTravel    Travel_Rarely       Travel_Frequently
# Department                Sales  Research & Development
# DistanceFromHome              6                      10
#
#                                     2                       3     \
# Age                                   32                      38
# Attrition                             No                      No
# BusinessTravel         Travel_Frequently              Non-Travel
# Department        Research & Development  Research & Development
# DistanceFromHome                      17                       2
#
#                                     4                       5     \
# Age                                   32                      46
# Attrition                             No                      No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, Age to YearsWithCurrManager
# Columns: 4410 entries, 0 to 4409
# dtypes: object(4410)
# memory usage: 413.5+ KB

# %%
df.isnull()
# Out:
#                           0      1      2      3      4      5      6     \
# Age                      False  False  False  False  False  False  False
# Attrition                False  False  False  False  False  False  False
# BusinessTravel           False  False  False  False  False  False  False
# Department               False  False  False  False  False  False  False
# DistanceFromHome         False  False  False  False  False  False  False
# Education                False  False  False  False  False  False  False
# EducationField           False  False  False  False  False  False  False
# EmployeeCount            False  False  False  False  False  False  False
# EmployeeID               False  False  False  False  False  False  False
# Gender                   False  False  False  False  False  False  False
# JobLevel                 False  False  False  False  False  False  False
# JobRole                  False  False  False  False  False  False  False
# ...

# %%
df.dropna()
# Out:
#                                               0                       1     \
# Age                                             51                      31
# Attrition                                       No                     Yes
# BusinessTravel                       Travel_Rarely       Travel_Frequently
# Department                                   Sales  Research & Development
# DistanceFromHome                                 6                      10
# Education                                        2                       1
# EducationField                       Life Sciences           Life Sciences
# EmployeeCount                                    1                       1
# EmployeeID                                       1                       2
# Gender                                      Female                  Female
# JobLevel                                         1                       1
# ...

# %%
df.duplicated()
# Out:
# Age                        False
# Attrition                  False
# BusinessTravel             False
# Department                 False
# DistanceFromHome           False
# Education                  False
# EducationField             False
# EmployeeCount              False
# EmployeeID                 False
# Gender                     False
# JobLevel                   False
# JobRole                    False
# MaritalStatus              False
# MonthlyIncome              False
# NumCompaniesWorked         False
# Over18                     False
# PercentSalaryHike          False
# StandardHours              False
# StockOptionLevel           False
# TotalWorkingYears          False
# TrainingTimesLastYear      False
# YearsAtCompany             False
# YearsSinceLastPromotion    False
# YearsWithCurrManager       False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#                                               0                       1     \
# Age                                             51                      31
# Attrition                                       No                     Yes
# BusinessTravel                       Travel_Rarely       Travel_Frequently
# Department                                   Sales  Research & Development
# DistanceFromHome                                 6                      10
# Education                                        2                       1
# EducationField                       Life Sciences           Life Sciences
# EmployeeCount                                    1                       1
# EmployeeID                                       1                       2
# Gender                                      Female                  Female
# JobLevel                                         1                       1
# ...

# %%
df.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
